# %% [markdown]
# # Demo Workflow
#
# This notebook is the presentation-friendly walkthrough for the lineup-aware defensive scheme simulator and recommendation engine.

# %%
from src.demo import build_default_case_studies, format_demo_result, run_demo_for_lineups, train_demo_artifacts

# %%
dataset, artifacts = train_demo_artifacts(season='2024-25')
case_studies = build_default_case_studies(dataset, min_minutes=10.0)
case_studies[['case_label', 'team_abbreviation', 'lineup_name', 'minutes_played', 'defensive_rating_target']]

# %%
demo_results = run_demo_for_lineups(case_studies, artifacts, case_label_column='case_label')
for result in demo_results:
    print(format_demo_result(result))
    print('\n' + '=' * 80 + '\n')
